# %%
# 1. Declarando a variável de entrada (Quantidade de primos desejada)
n_desejado = int(input())

# 2. Criando o método
def determinando_primos(n):
    quantidade_encontrada = 0
    candidato = 2  # O primeiro número a ser testado

    while quantidade_encontrada < n_desejado:
        # A variável 'divisores' conta quantas vezes o candidato foi dividido
        divisores = 0

        # O for testa todos os números entre 2 e o candidato-1
        for divisor in range(2, candidato):
            if candidato % divisor == 0:
                divisores = divisores + 1

        # Se não houve divisores além de 1 e ele mesmo, ele é primo
        if divisores == 0:
            print(candidato)
            quantidade_encontrada = quantidade_encontrada + 1

        # IMPORTANTE: Aumentamos o candidato para testar o próximo número
        candidato = candidato + 1

# 3. Executando o método
determinando_primos(n_desejado)
# Out:
# 2
# 180
